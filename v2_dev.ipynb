# %%
from core.box import Matrix
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
Matrix().LOOP()
# Out:
# ┌─────────┐
# │         │
# │         │
# │         │
# │         │
# │         │
# │         │
# │         │
# │         │
# │         │
# └─────────┘
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Matrix().LOOP()
#
# File ~/Application/aicube/core/box.py:39, in Matrix.LOOP(self)
#      37 def LOOP(self):
#      38     while self.running:
# ---> 39         dt, keys = self.Tick(20)
#      40         self.grid.render()
#      41         pygame.display.flip()
#
# File ~/Application/aicube/core/box.py:31, in Matrix.Tick(self, t)
#      30 def Tick(self, t:int=20):
# ---> 31     self.clock.tick(20)
#      32     dt = self.clock.get_time() / 1000.0
#      33     keys = pygame.key.get_pressed()
#
# KeyboardInterrupt:
